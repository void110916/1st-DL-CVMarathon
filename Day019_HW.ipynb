# %%
import numpy as np
from keras.models import Model
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras import backend as K
from keras import layers
from keras.layers import BatchNormalization
from keras.layers import Activation

def Conv2d_bn(x,filters,kernel_size,padding='same',strides=(1, 1),normalizer=True,activation='relu',name=None):
    if name is not None:
        conv_name = name + '_conv'
        bn_name = name + '_bn'
        act_name = name + '_act'
    else:
        conv_name = None
        bn_name = None
        act_name = None
    if K.image_data_format() == 'channels_first':
        bn_axis = 1
    else:
        bn_axis = 3
    x = Conv2D(
            filters, kernel_size,
            strides=strides, padding=padding,
            use_bias=False, name=conv_name)(x)
    if normalizer:
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    if activation:
        x = Activation(activation, name=act_name)(x)
    return x

def InceptionV1_block(x, specs,channel_axis, name):
    (br0, br1, br2, br3) = specs   # ((64,), (96,128), (16,32), (32,))
    branch_0 = Conv2d_bn(x, br0[0], (1, 1), name=name+"_Branch_0")

    branch_1 = Conv2d_bn(x, br1[0], (1, 1), name=name+"_Branch_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (3, 3), name=name+"_Branch_1_1")

    '''Branch_2'''
    branch_2=Conv2d_bn(x, br2[0], (1, 1), name=name+"_Branch_2")
    branch_2=Conv2d_bn(branch_2, br2[1], (3, 3), name=name+"_Branch_2_1")
    '''Branch_3'''
    branch_3=MaxPooling2D((3, 3), strides=(1, 1),padding='same', name=name+'_Branch_3')(x)
    branch_3=Conv2d_bn(branch_3, br3[0], (1, 1), name=name+"_Branch_3_1")

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name=name+"_Concatenated")
    return x

# img_input = Input(shape=(224,224,1))
# x=InceptionV1_block(img_input, ((64,), (96,128), (16,32), (32,)), 3, 'Block_1')
# print(x)

def InceptionV3_block(x, specs,channel_axis, name):
    (br0, br1, br2, br3) = specs   # ((64,), (96,128), (16,32), (32,))
    branch_0 = Conv2d_bn(x, br0[0], (1, 1), name=name+"_Branch_0")

    branch_1 = Conv2d_bn(x, br1[0], (1, 1), name=name+"_Branch_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (1, 3), name=name+"_Branch_1_1")
    branch_1 = Conv2d_bn(branch_1, br1[1], (3, 1), name=name+"_Branch_1_2")

    '''Branch_2'''
    branch_2=Conv2d_bn(x, br2[0], (1, 1), name=name+"_Branch_2")
    branch_2=Conv2d_bn(branch_2, br2[1], (1, 3), name=name+"_Branch_2_1")
    branch_2=Conv2d_bn(branch_2, br2[1], (3, 1), name=name+"_Branch_2_2")
    '''Branch_3'''
    branch_3=MaxPooling2D((3, 3), strides=(1, 1),padding='same', name=name+'_Branch_3')(x)
    branch_3=Conv2d_bn(branch_3, br3[0], (1, 1), name=name+"_Branch_3_1")

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name=name+"_Concatenated")
    return x

# img_input = Input(shape=(224,224,1))
# x=InceptionV3_block(img_input, ((64,), (96,128), (16,32), (32,)), 3, 'Block_1')
# print(x)

def VGG16_Inception(include_top=True,input_tensor=None, input_shape=(224,224,1),
          pooling='max',classes=1000):
 
    img_input = Input(shape=input_shape)

    x = Conv2d_bn(img_input, 64, (3, 3), activation='relu', padding='same', name='block1_conv1')
    x = Conv2d_bn(x, 64, kernel_size=(3, 3), activation='relu', padding='same', name='block1_conv2')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2d_bn(x, 128, (3, 3), activation='relu', padding='same', name='block2_conv1')
    x = Conv2d_bn(x, 128, (3, 3), activation='relu', padding='same', name='block2_conv2')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = InceptionV1_block(x, ((64,), (96,128), (16,32), (32,)), 3, name='Block_1')
    x = InceptionV1_block(x, ((64,), (96,128), (16,32), (32,)), 3, name='Block_2')
    x = InceptionV1_block(x, ((64,), (96,128), (16,32), (32,)), 3, name='Block_3')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2d_bn(x, 512, (3, 3), activation='relu', padding='same', name='block4_conv1')
    x = Conv2d_bn(x, 512, (3, 3), activation='relu', padding='same', name='block4_conv2')
    x = Conv2d_bn(x, 512, (3, 3), activation='relu', padding='same', name='block4_conv3')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = InceptionV3_block(x, ((128,), (192,256), (32,64), (64,)), 3, name='Block4')
    x = InceptionV3_block(x, ((128,), (192,256), (32,64), (64,)), 3, name='Block5')
    x = InceptionV3_block(x, ((128,), (192,256), (32,64), (64,)), 3, name='Block6')
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    if include_top:
        # Classification block
        x = Flatten(name='flatten')(x)
        x = Dense(4096, activation='relu', name='fc1')(x)
        x = Dense(4096, activation='relu', name='fc2')(x)
        x = Dense(classes, activation='softmax', name='predictions')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)

    inputs = img_input
    # Create model.
    model = Model(inputs, x, name='vgg16')

   
    return model

model = VGG16_Inception(include_top=False)
model.summary()
# Out:
# ___________________
# Block_3_Branch_2_1_act (Activat (None, 56, 56, 32)   0           Block_3_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_3_Branch_3_1_act (Activat (None, 56, 56, 32)   0           Block_3_Branch_3_1_bn[0][0]
# __________________________________________________________________________________________________
# Block_3_Concatenated (Concatena (None, 56, 56, 256)  0           Block_3_Branch_0_act[0][0]
#                                                                  Block_3_Branch_1_1_act[0][0]
#                                                                  Block_3_Branch_2_1_act[0][0]
#                                                                  Block_3_Branch_3_1_act[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           Block_3_Concatenated[0][0]
# __________________________________________________________________________________________________
# block4_conv1_conv (Conv2D)      (None, 28, 28, 512)  1179648     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv1_bn (BatchNormaliza (None, 28, 28, 512)  1536        block4_conv1_conv[0][0]
# __________________________________________________________________________________________________
# block4_conv1_act (Activation)   (None, 28, 28, 512)  0           block4_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_conv2_conv (Conv2D)      (None, 28, 28, 512)  2359296     block4_conv1_act[0][0]
# __________________________________________________________________________________________________
# block4_conv2_bn (BatchNormaliza (None, 28, 28, 512)  1536        block4_conv2_conv[0][0]
# __________________________________________________________________________________________________
# block4_conv2_act (Activation)   (None, 28, 28, 512)  0           block4_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block4_conv3_conv (Conv2D)      (None, 28, 28, 512)  2359296     block4_conv2_act[0][0]
# __________________________________________________________________________________________________
# block4_conv3_bn (BatchNormaliza (None, 28, 28, 512)  1536        block4_conv3_conv[0][0]
# __________________________________________________________________________________________________
# block4_conv3_act (Activation)   (None, 28, 28, 512)  0           block4_conv3_bn[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3_act[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_conv (Conv2D)   (None, 14, 14, 192)  98304       block4_pool[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_conv (Conv2D)   (None, 14, 14, 32)   16384       block4_pool[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_bn (BatchNormal (None, 14, 14, 192)  576         Block4_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_bn (BatchNormal (None, 14, 14, 32)   96          Block4_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_act (Activation (None, 14, 14, 192)  0           Block4_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_act (Activation (None, 14, 14, 32)   0           Block4_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_1_conv (Conv2D) (None, 14, 14, 256)  147456      Block4_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_1_conv (Conv2D) (None, 14, 14, 64)   6144        Block4_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_1_bn (BatchNorm (None, 14, 14, 256)  768         Block4_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_1_bn (BatchNorm (None, 14, 14, 64)   192         Block4_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_1_act (Activati (None, 14, 14, 256)  0           Block4_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_1_act (Activati (None, 14, 14, 64)   0           Block4_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_3 (MaxPooling2D)  (None, 14, 14, 512)  0           block4_pool[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_0_conv (Conv2D)   (None, 14, 14, 128)  65536       block4_pool[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_2_conv (Conv2D) (None, 14, 14, 256)  196608      Block4_Branch_1_1_act[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_2_conv (Conv2D) (None, 14, 14, 64)   12288       Block4_Branch_2_1_act[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_3_1_conv (Conv2D) (None, 14, 14, 64)   32768       Block4_Branch_3[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_0_bn (BatchNormal (None, 14, 14, 128)  384         Block4_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_2_bn (BatchNorm (None, 14, 14, 256)  768         Block4_Branch_1_2_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_2_bn (BatchNorm (None, 14, 14, 64)   192         Block4_Branch_2_2_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_3_1_bn (BatchNorm (None, 14, 14, 64)   192         Block4_Branch_3_1_conv[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_0_act (Activation (None, 14, 14, 128)  0           Block4_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_1_2_act (Activati (None, 14, 14, 256)  0           Block4_Branch_1_2_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_2_2_act (Activati (None, 14, 14, 64)   0           Block4_Branch_2_2_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Branch_3_1_act (Activati (None, 14, 14, 64)   0           Block4_Branch_3_1_bn[0][0]
# __________________________________________________________________________________________________
# Block4_Concatenated (Concatenat (None, 14, 14, 512)  0           Block4_Branch_0_act[0][0]
#                                                                  Block4_Branch_1_2_act[0][0]
#                                                                  Block4_Branch_2_2_act[0][0]
#                                                                  Block4_Branch_3_1_act[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_conv (Conv2D)   (None, 14, 14, 192)  98304       Block4_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_conv (Conv2D)   (None, 14, 14, 32)   16384       Block4_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_bn (BatchNormal (None, 14, 14, 192)  576         Block5_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_bn (BatchNormal (None, 14, 14, 32)   96          Block5_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_act (Activation (None, 14, 14, 192)  0           Block5_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_act (Activation (None, 14, 14, 32)   0           Block5_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_1_conv (Conv2D) (None, 14, 14, 256)  147456      Block5_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_1_conv (Conv2D) (None, 14, 14, 64)   6144        Block5_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_1_bn (BatchNorm (None, 14, 14, 256)  768         Block5_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_1_bn (BatchNorm (None, 14, 14, 64)   192         Block5_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_1_act (Activati (None, 14, 14, 256)  0           Block5_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_1_act (Activati (None, 14, 14, 64)   0           Block5_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_3 (MaxPooling2D)  (None, 14, 14, 512)  0           Block4_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_0_conv (Conv2D)   (None, 14, 14, 128)  65536       Block4_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_2_conv (Conv2D) (None, 14, 14, 256)  196608      Block5_Branch_1_1_act[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_2_conv (Conv2D) (None, 14, 14, 64)   12288       Block5_Branch_2_1_act[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_3_1_conv (Conv2D) (None, 14, 14, 64)   32768       Block5_Branch_3[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_0_bn (BatchNormal (None, 14, 14, 128)  384         Block5_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_2_bn (BatchNorm (None, 14, 14, 256)  768         Block5_Branch_1_2_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_2_bn (BatchNorm (None, 14, 14, 64)   192         Block5_Branch_2_2_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_3_1_bn (BatchNorm (None, 14, 14, 64)   192         Block5_Branch_3_1_conv[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_0_act (Activation (None, 14, 14, 128)  0           Block5_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_1_2_act (Activati (None, 14, 14, 256)  0           Block5_Branch_1_2_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_2_2_act (Activati (None, 14, 14, 64)   0           Block5_Branch_2_2_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Branch_3_1_act (Activati (None, 14, 14, 64)   0           Block5_Branch_3_1_bn[0][0]
# __________________________________________________________________________________________________
# Block5_Concatenated (Concatenat (None, 14, 14, 512)  0           Block5_Branch_0_act[0][0]
#                                                                  Block5_Branch_1_2_act[0][0]
#                                                                  Block5_Branch_2_2_act[0][0]
#                                                                  Block5_Branch_3_1_act[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_conv (Conv2D)   (None, 14, 14, 192)  98304       Block5_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_conv (Conv2D)   (None, 14, 14, 32)   16384       Block5_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_bn (BatchNormal (None, 14, 14, 192)  576         Block6_Branch_1_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_bn (BatchNormal (None, 14, 14, 32)   96          Block6_Branch_2_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_act (Activation (None, 14, 14, 192)  0           Block6_Branch_1_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_act (Activation (None, 14, 14, 32)   0           Block6_Branch_2_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_1_conv (Conv2D) (None, 14, 14, 256)  147456      Block6_Branch_1_act[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_1_conv (Conv2D) (None, 14, 14, 64)   6144        Block6_Branch_2_act[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_1_bn (BatchNorm (None, 14, 14, 256)  768         Block6_Branch_1_1_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_1_bn (BatchNorm (None, 14, 14, 64)   192         Block6_Branch_2_1_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_1_act (Activati (None, 14, 14, 256)  0           Block6_Branch_1_1_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_1_act (Activati (None, 14, 14, 64)   0           Block6_Branch_2_1_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_3 (MaxPooling2D)  (None, 14, 14, 512)  0           Block5_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_0_conv (Conv2D)   (None, 14, 14, 128)  65536       Block5_Concatenated[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_2_conv (Conv2D) (None, 14, 14, 256)  196608      Block6_Branch_1_1_act[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_2_conv (Conv2D) (None, 14, 14, 64)   12288       Block6_Branch_2_1_act[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_3_1_conv (Conv2D) (None, 14, 14, 64)   32768       Block6_Branch_3[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_0_bn (BatchNormal (None, 14, 14, 128)  384         Block6_Branch_0_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_2_bn (BatchNorm (None, 14, 14, 256)  768         Block6_Branch_1_2_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_2_bn (BatchNorm (None, 14, 14, 64)   192         Block6_Branch_2_2_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_3_1_bn (BatchNorm (None, 14, 14, 64)   192         Block6_Branch_3_1_conv[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_0_act (Activation (None, 14, 14, 128)  0           Block6_Branch_0_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_1_2_act (Activati (None, 14, 14, 256)  0           Block6_Branch_1_2_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_2_2_act (Activati (None, 14, 14, 64)   0           Block6_Branch_2_2_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Branch_3_1_act (Activati (None, 14, 14, 64)   0           Block6_Branch_3_1_bn[0][0]
# __________________________________________________________________________________________________
# Block6_Concatenated (Concatenat (None, 14, 14, 512)  0           Block6_Branch_0_act[0][0]
#                                                                  Block6_Branch_1_2_act[0][0]
#                                                                  Block6_Branch_2_2_act[0][0]
#                                                                  Block6_Branch_3_1_act[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           Block6_Concatenated[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 512)          0           block5_pool[0][0]
# ==================================================================================================
# Total params: 8,380,624
# Trainable params: 8,368,240
# Non-trainable params: 12,384
# __________________________________________________________________________________________________
